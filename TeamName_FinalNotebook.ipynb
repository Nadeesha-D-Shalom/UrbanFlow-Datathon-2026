# %% [markdown]
# # UrbanFlow final notebook
#
# Template only. Replace TeamName in the filename before submission.
#
# ## 1. Data quality and EDA
#
# ## 2. Fare and duration prediction
#
# ## 3. Demand forecasting, hotspots and flows
#
# ## 4. Evaluation, architecture and business conclusions
#
# Integrate executable steps and reported results here before submission.
