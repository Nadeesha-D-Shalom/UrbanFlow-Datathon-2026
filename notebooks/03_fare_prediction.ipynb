# %% [markdown]
# # Fare prediction
#
# Starter outline: implementation pending.
#
# Build baselines and candidate pipelines; evaluate MAE, RMSE and R2; export the pipeline.

# %%
from pathlib import Path
import json
import sys

ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / "configs/paths.json").is_file())
sys.path.insert(0, str(ROOT / "src"))
paths = json.loads((ROOT / "configs/paths.json").read_text(encoding="utf-8"))
